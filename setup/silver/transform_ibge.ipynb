# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

df_ibge = spark.table("projeto_final_bronze.bronze_ibge_censo_2022")
df_ibge = df_ibge.toPandas()

df_ibge.head()
